# %%
print("Hello there")
# Out:
# Hello there

# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')

print(df.head(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
# Read headers
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(df['Name'][:5])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
# print each column
print(df[['Name','HP']])
# Out:
#                       Name  HP
# 0                Bulbasaur  45
# 1                  Ivysaur  60
# 2                 Venusaur  80
# 3    VenusaurMega Venusaur  80
# 4               Charmander  39
# ..                     ...  ..
# 795                Diancie  50
# 796    DiancieMega Diancie  50
# 797    HoopaHoopa Confined  80
# 798     HoopaHoopa Unbound  80
# 799              Volcanion  80
#
# [800 rows x 2 columns]

# %%
# print each row
print(df.iloc[4:6])
# Out:
#    #        Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 4  4  Charmander   Fire    NaN  39      52       43       60       50     65
# 5  5  Charmeleon   Fire    NaN  58      64       58       80       65     80
#
#    Generation  Legendary
# 4           1      False
# 5           1      False

# %%
print(df.iloc[0,1])
# Out:
# Bulbasaur

# %%
# specific feature
# get a particular number having a similar feature
df.loc[df['Type 1'] == "Fire"][:5]
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False

# %%
# sorting
df.loc[df['HP'] > 40].sort_values(['HP'], ascending = False)[:10]
# Out:
#        #                   Name   Type 1  Type 2   HP  Attack  Defense  \
# 261  242                Blissey   Normal     NaN  255      10       10
# 121  113                Chansey   Normal     NaN  250       5        5
# 217  202              Wobbuffet  Psychic     NaN  190      33       58
# 351  321                Wailord    Water     NaN  170      90       45
# 655  594              Alomomola    Water     NaN  165      75       80
# 155  143                Snorlax   Normal     NaN  160     110       65
# 473  426               Drifblim    Ghost  Flying  150      80       44
# 313  289                Slaking   Normal     NaN  150     160      100
# 545  487   GiratinaOrigin Forme    Ghost  Dragon  150     120      100
# 544  487  GiratinaAltered Forme    Ghost  Dragon  150     100      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 261       75      135     55           2      False
# 121       35      105     50           1      False
# ...

# %%
# looking at your data
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# making changes to your data # adding a column
df['Total Strength'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def']
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total Strength
# 0       65     45           1      False             273
# 1       80     60           1      False             345
# 2      100     80           1      False             445
# 3      120     80           1      False             545
# 4       50     65           1      False             244

# %%
# dropping a column
df = df.drop(columns = 'Total Strength')
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# adding rows and making a column
df['Max Strength'] = df.iloc[:, 4:10].sum(axis = 1)
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Max Strength
# 0       65     45           1      False           318
# 1       80     60           1      False           405
# 2      100     80           1      False           525
# 3      120     80           1      False           625
# 4       50     65           1      False           309

# %%
# reordering the columns
# create a list of the column names
cols_list = list(df.columns)
new_df = df[cols_list[:4] + cols_list[5:8]]
new_df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Attack  Defense  Sp. Atk
# 0  1              Bulbasaur  Grass  Poison      49       49       65
# 1  2                Ivysaur  Grass  Poison      62       63       80
# 2  3               Venusaur  Grass  Poison      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison     100      123      122
# 4  4             Charmander   Fire     NaN      52       43       60

# %%
print(df.columns.get_loc('Type 1'))
# Out:
# 2

# %%
a_dataframe = pd.DataFrame({"Letters": ["a", "b", "c"], "Numbers": [1, 2, 3]})
print(a_dataframe.columns.get_loc('Letters'))
# Out:
# 0

# %%
# getting location and creating dataframe
new_df = df[cols_list[df.columns.get_loc('#'):df.columns.get_loc('Generation')]]
new_df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed
# 0       65     45
# 1       80     60
# 2      100     80
# 3      120     80
# 4       50     65

# %%
# getting rid of the index
new_df.to_csv('modified_data.csv', index = False)

# %%
# Filtering data
grass_poison = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]

gp = grass_poison.reset_index(drop = True)
gp
# Out:
#       #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0     1              Bulbasaur  Grass  Poison   45      49       49       65
# 1     2                Ivysaur  Grass  Poison   60      62       63       80
# 2     3               Venusaur  Grass  Poison   80      82       83      100
# 3     3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4    43                 Oddish  Grass  Poison   45      50       55       75
# 5    44                  Gloom  Grass  Poison   60      65       70       85
# 6    45              Vileplume  Grass  Poison   75      80       85      110
# 7    69             Bellsprout  Grass  Poison   50      75       35       70
# 8    70             Weepinbell  Grass  Poison   65      90       50       85
# 9    71             Victreebel  Grass  Poison   80     105       65      100
# 10  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
# filtering out mega in string
wm = df.loc[~df['Name'].str.contains('Mega')]
wm
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %%
# conditional changes
# changing the max strength of legendaries into infinity
df.loc[df['Legendary'] == True, ['Max Strength']] = 'infinity'
df.loc[df['Legendary'] == True]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary Max Strength
# ...

# %%
# group by TYPE 1 and find the mean and sort them by HP
df = pd.read_csv('modified_data.csv')
df.groupby(['Type 1']).mean().sort_values('HP', ascending =False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Normal    319.173469  77.275510   73.469388   59.846939  55.816327  63.724490
# Fairy     449.529412  74.117647   61.529412   65.705882  78.529412  84.705882
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Psychic   380.807018  70.631579   71.456140   67.684211  98.403509  86.280702
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# ...

# %%
# count
df.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Type 1
# Bug        69    69      52   69      69       69       69       69     69
# Dark       31    31      21   31      31       31       31       31     31
# Dragon     32    32      21   32      32       32       32       32     32
# Electric   44    44      17   44      44       44       44       44     44
# Fairy      17    17       2   17      17       17       17       17     17
# Fighting   27    27       7   27      27       27       27       27     27
# Fire       52    52      24   52      52       52       52       52     52
# Flying      4     4       2    4       4        4        4        4      4
# Ghost      32    32      22   32      32       32       32       32     32
# Grass      70    70      37   70      70       70       70       70     70
# Ground     32    32      19   32      32       32       32       32     32
# ...

# %%
df['Count'] = 1
df.groupby(['Type 1', 'Type 2']).count()['Count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: Count, Length: 136, dtype: int64

# %%
df2 = df.head(5)
df2.loc[2] = [2,'MinaSaur', 'Grass', 'Poison', '40', '70', 23,123,4,1,1]
# Out:
# c:\users\nasif\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py:1700: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, v, pi)
